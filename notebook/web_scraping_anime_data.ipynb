# %%
import requests
import pandas as pd
from pyspark.sql import SparkSession

# Initialize Spark session
spark = SparkSession.builder.appName("AnimeDataIngestion").getOrCreate()

# API URL
url = "https://api.jikan.moe/v4/anime"

# Fetch data
response = requests.get(url)
data = response.json()

# Extract anime list
anime_list = data["data"]

# Convert to Pandas DataFrame
pdf = pd.DataFrame(anime_list)

# Convert to Spark DataFrame
df = spark.createDataFrame(pdf)

# Show first few rows
df.show(5)
# Out:
# StatementMeta(, 6a641e71-3444-49a6-abf9-8953416b20dc, 10, Finished, Available, Finished)
# +------+--------------------+--------------------+--------------------+--------+--------------------+--------------------+--------------------+---------------------------+--------------------+-----+--------+--------+---------------+------+--------------------+-------------+--------------------+-----+---------+----+----------+-------+---------+--------------------+--------------------+------+------+--------------------+--------------------+--------------------+--------------------+--------------------+---------------+--------------------+--------------------+
# |mal_id|                 url|              images|             trailer|approved|              titles|               title|       title_english|             title_japanese|      title_synonyms| type|  source|episodes|         status|airing|               aired|     duration|              rating|score|scored_by|rank|popularity|members|favorites|            synopsis|          background|season|  year|           broadcast|           producers|           licensors|             studios|              genres|explicit_genres|              themes|        demographics|
# +------+--------------------+--------------------+--------------------+--------+--------------------+--------------------+--------------------+---------------------------+--------------------+-----+--------+--------+---------------+------+--------------------+-------------+--------------------+-----+---------+----+----------+-------+---------+--------------------+--------------------+------+------+--------------------+--------------------+--------------------+--------------------+--------------------+---------------+--------------------+--------------------+
# |     1|https://myanimeli...|{{https://cdn.mya...|{https://www.yout...|    true|[{Cowboy Bebop, D...|        Cowboy Bebop|        Cowboy Bebop|         カウボーイビバップ|                  []|   TV|Original|    26.0|Finished Airing| false|{1998-04-03T00:00...|24 min per ep|R - 17+ (violence...| 8.75|  1039717|  48|        42|2013594|    88144|Crime is timeless...|When Cowboy Bebop...|spring|1998.0|{Saturdays, Satur...|[{23, Bandai Visu...|[{102, Funimation...|[{14, Sunrise, an...|[{1, Action, anim...|             []|[{50, Adult Cast,...|                  []|
# |     5|https://myanimeli...|{{https://cdn.mya...|{NULL, {NULL, NUL...|    true|[{Cowboy Bebop: T...|Cowboy Bebop: Ten...|Cowboy Bebop: The...|カウボーイビバップ 天国の扉|[Cowboy Bebop: Kn...|Movie|Original|     1.0|Finished Airing| false|{2001-09-01T00:00...|  1 hr 55 min|R - 17+ (violence...| 8.38|   228552| 233|       649| 404524|     1747|Another day, anot...|                    |  NULL|  NULL|{NULL, NULL, NULL...|[{14, Sunrise, an...|[{15, Sony Pictur...|[{4, Bones, anime...|[{1, Action, anim...|             []|[{50, Adult Cast,...|                  []|
# |     6|https://myanimeli...|{{https://cdn.mya...|{https://www.yout...|    true|[{Trigun, Default...|              Trigun|              Trigun|                 トライガン|                  []|   TV|   Manga|    26.0|Finished Airing| false|{1998-04-01T00:00...|24 min per ep|PG-13 - Teens 13 ...| 8.22|   394751| 386|       266| 817335|    17251|Vash the Stampede...|The Japanese rele...|spring|1998.0|{Thursdays, Thurs...|[{123, Victor Ent...|[{102, Funimation...|[{11, Madhouse, a...|[{1, Action, anim...|             []|[{50, Adult Cast,...|[{27, Shounen, an...|
# |     7|https://myanimeli...|{{https://cdn.mya...|{https://www.yout...|    true|[{Witch Hunter Ro...|  Witch Hunter Robin|  Witch Hunter Robin|       Witch Hunter ROBI...|               [WHR]|   TV|Original|    26.0|Finished Airing| false|{2002-07-03T00:00...|25 min per ep|PG-13 - Teens 13 ...| 7.23|    45872|3344|      1981| 126250|      690|Though hidden awa...|                    |summer|2002.0|{Wednesdays, Wedn...|[{23, Bandai Visu...|[{102, Funimation...|[{14, Sunrise, an...|[{1, Action, anim...|             []|[{39, Detective, ...|                  []|
# |     8|https://myanimeli...|{{https://cdn.mya...|{NULL, {NULL, NUL...|    true|[{Bouken Ou Beet,...|      Bouken Ou Beet|Beet the Vandel B...|               冒険王ビィト|[Adventure King B...|   TV|   Manga|    52.0|Finished Airing| false|{2004-09-30T00:00...|23 min per ep|       PG - Children| 6.92|     6989|4885|      5773|  16481|       18|It is the dark ce...|                    |  fall|2004.0|{Thursdays, Thurs...|[{16, TV Tokyo, a...|[{2262, Illumitoo...|[{18, Toei Animat...|[{1, Action, anim...|             []|                  []|[{27, Shounen, an...|
# +------+--------------------+--------------------+--------------------+--------+--------------------+--------------------+--------------------+---------------------------+--------------------+-----+--------+--------+---------------+------+--------------------+-------------+--------------------+-----+---------+----+----------+-------+---------+--------------------+--------------------+------+------+--------------------+--------------------+--------------------+--------------------+--------------------+---------------+--------------------+--------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import col, when, size, lit

# 1. Extract studio and genre names safely
df_extracted = df.withColumn(
    "studio",
    when(
        (col("studios").isNotNull()) & (size(col("studios")) > 0),
        col("studios")[0]["name"]
    ).otherwise("Unknown")
).withColumn(
    "genre",
    when(
        (col("genres").isNotNull()) & (size(col("genres")) > 0),
        col("genres")[0]["name"]
    ).otherwise("Unknown")
)

# 2. Select and rename columns
df_selected = df_extracted.select(
    col("mal_id").alias("anime_id"),
    col("title"),
    col("title_english"),
    col("type"),
    col("source"),
    col("episodes"),
    col("status"),
    col("duration"),
    col("rating"),
    col("score"),
    col("scored_by"),
    col("rank"),
    col("popularity"),
    col("members"),
    col("favorites"),
    col("season"),
    col("year"),
    col("studio"),
    col("genre")
)

# 3. Fill nulls
df_clean = df_selected.fillna({
    "title_english": "Unknown",
    "score": 0.0,
    "episodes": 0,
    "studio": "Unknown",
    "genre": "Unknown"
})

# 4. Cast types
df_final = df_clean \
    .withColumn("score", col("score").cast("float")) \
    .withColumn("episodes", col("episodes").cast("int")) \
    .withColumn("members", col("members").cast("int")) \
    .withColumn("favorites", col("favorites").cast("int")) \
    .withColumn("rank", col("rank").cast("int")) \
    .withColumn("popularity", col("popularity").cast("int"))

# Show result
print("✅ Final DataFrame schema:")
df_final.printSchema()

print("\n✅ Sample data:")
df_final.show(10, truncate=False)

# Count rows
print(f"\n✅ Total records: {df_final.count()}")
# Out:
# StatementMeta(, 6a641e71-3444-49a6-abf9-8953416b20dc, 15, Finished, Available, Finished)
# ✅ Final DataFrame schema:
# root
#  |-- anime_id: long (nullable = true)
#  |-- title: string (nullable = true)
#  |-- title_english: string (nullable = false)
#  |-- type: string (nullable = true)
#  |-- source: string (nullable = true)
#  |-- episodes: integer (nullable = true)
#  |-- status: string (nullable = true)
#  |-- duration: string (nullable = true)
#  |-- rating: string (nullable = true)
#  |-- score: float (nullable = false)
#  |-- scored_by: long (nullable = true)
#  |-- rank: integer (nullable = true)
#  |-- popularity: integer (nullable = true)
#  |-- members: integer (nullable = true)
#  |-- favorites: integer (nullable = true)
#  |-- season: string (nullable = true)
#  |-- year: double (nullable = true)
#  |-- studio: string (nullable = false)
#  |-- genre: string (nullable = false)
#
#
# ✅ Sample data:
# +--------+-------------------------------+-----------------------+-----+--------+--------+---------------+-------------+------------------------------+-----+---------+----+----------+-------+---------+------+------+----------------+------+
# |anime_id|title                          |title_english          |type |source  |episodes|status         |duration     |rating                        |score|scored_by|rank|popularity|members|favorites|season|year  |studio          |genre |
# +--------+-------------------------------+-----------------------+-----+--------+--------+---------------+-------------+------------------------------+-----+---------+----+----------+-------+---------+------+------+----------------+------+
# |1       |Cowboy Bebop                   |Cowboy Bebop           |TV   |Original|26      |Finished Airing|24 min per ep|R - 17+ (violence & profanity)|8.75 |1039717  |48  |42        |2013594|88144    |spring|1998.0|Sunrise         |Action|
# |5       |Cowboy Bebop: Tengoku no Tobira|Cowboy Bebop: The Movie|Movie|Original|1       |Finished Airing|1 hr 55 min  |R - 17+ (violence & profanity)|8.38 |228552   |233 |649       |404524 |1747     |NULL  |NULL  |Bones           |Action|
# |6       |Trigun                         |Trigun                 |TV   |Manga   |26      |Finished Airing|24 min per ep|PG-13 - Teens 13 or older     |8.22 |394751   |386 |266       |817335 |17251    |spring|1998.0|Madhouse        |Action|
# |7       |Witch Hunter Robin             |Witch Hunter Robin     |TV   |Original|26      |Finished Airing|25 min per ep|PG-13 - Teens 13 or older     |7.23 |45872    |3344|1981      |126250 |690      |summer|2002.0|Sunrise         |Action|
# |8       |Bouken Ou Beet                 |Beet the Vandel Buster |TV   |Manga   |52      |Finished Airing|23 min per ep|PG - Children                 |6.92 |6989     |4885|5773      |16481  |18       |fall  |2004.0|Toei Animation  |Action|
# |15      |Eyeshield 21                   |Unknown                |TV   |Manga   |145     |Finished Airing|23 min per ep|PG-13 - Teens 13 or older     |7.91 |92696    |841 |1393      |193852 |2103     |spring|2005.0|Gallop          |Sports|
# |16      |Hachimitsu to Clover           |Honey and Clover       |TV   |Manga   |24      |Finished Airing|23 min per ep|PG-13 - Teens 13 or older     |7.98 |86369    |727 |960       |282133 |4192     |spring|2005.0|J.C.Staff       |Comedy|
# |17      |Hungry Heart: Wild Striker     |Unknown                |TV   |Manga   |52      |Finished Airing|23 min per ep|PG-13 - Teens 13 or older     |7.54 |14056    |1903|4780      |26520  |245      |fall  |2002.0|Nippon Animation|Sports|
# |18      |Initial D Fourth Stage         |Unknown                |TV   |Manga   |24      |Finished Airing|27 min per ep|PG-13 - Teens 13 or older     |8.17 |116475   |455 |1292      |209504 |1403     |spring|2004.0|A.C.G.T.        |Action|
# |19      |Monster                        |Monster                |TV   |Manga   |74      |Finished Airing|24 min per ep|R+ - Mild Nudity              |8.89 |490005   |25  |119       |1280722|59973    |spring|2004.0|Madhouse        |Drama |
# +--------+-------------------------------+-----------------------+-----+--------+--------+---------------+-------------+------------------------------+-----+---------+----+----------+-------+---------+------+------+----------------+------+
# only showing top 10 rows
#
#
# ✅ Total records: 25

# %%
# Write to Delta table in Lakehouse
df_final.write.mode("overwrite").format("delta").saveAsTable("anime_cleaned")

print("✅ Data saved as Delta table: anime_cleaned")
# Out:
# StatementMeta(, 6a641e71-3444-49a6-abf9-8953416b20dc, 16, Finished, Available, Finished)
# ✅ Data saved as Delta table: anime_cleaned

# %%
# Verify the table was created
tables = spark.sql("SHOW TABLES")
tables.show()

# Check if our table exists
if "anime_cleaned" in [row.tableName for row in tables.collect()]:
    print("✅ Table 'anime_cleaned' exists!")
    
    # Preview data from the table
    spark.sql("SELECT * FROM anime_cleaned LIMIT 5").show()
else:
    print("❌ Table not found. Let's create it...")
    
    # Create it manually if needed
    df_final.write.mode("overwrite").format("delta").saveAsTable("anime_cleaned")
    print("✅ Table created successfully!")
# Out:
# StatementMeta(, 6a641e71-3444-49a6-abf9-8953416b20dc, 17, Finished, Available, Finished)
# +---------------+-------------+-----------+
# |      namespace|    tableName|isTemporary|
# +---------------+-------------+-----------+
# |anime_lakehouse|anime_cleaned|      false|
# +---------------+-------------+-----------+
#
# ✅ Table 'anime_cleaned' exists!
# +--------+-------------+-------------+----+-----------+--------+---------------+-------------+--------------------+-----+---------+----+----------+-------+---------+------+------+--------------+-----------+
# |anime_id|        title|title_english|type|     source|episodes|         status|     duration|              rating|score|scored_by|rank|popularity|members|favorites|season|  year|        studio|      genre|
# +--------+-------------+-------------+----+-----------+--------+---------------+-------------+--------------------+-----+---------+----+----------+-------+---------+------+------+--------------+-----------+
# |      25|    Sunabouzu|  Desert Punk|  TV|      Manga|      24|Finished Airing|24 min per ep|R - 17+ (violence...| 7.36|    57575|2632|      1729| 149361|      872|  fall|2004.0|         Gonzo|     Action|
# |      26|   Texhnolyze|   Texhnolyze|  TV|   Original|      22|Finished Airing|23 min per ep|    R+ - Mild Nudity| 7.75|    62218|1215|       968| 280409|     5548|spring|2003.0|      Madhouse|Avant Garde|
# |      27|Trinity Blood|Trinity Blood|  TV|Light novel|      24|Finished Airing|24 min per ep|R - 17+ (violence...| 7.28|    83354|3017|      1378| 196605|     1395|spring|2005.0|         Gonzo|     Action|
# |      19|      Monster|      Monster|  TV|      Manga|      74|Finished Airing|24 min per ep|    R+ - Mild Nudity| 8.89|   490005|  25|       119|1280722|    59973|spring|2004.0|      Madhouse|      Drama|
# |      20|       Naruto|       Naruto|  TV|      Manga|     220|Finished Airing|23 min per ep|PG-13 - Teens 13 ...| 8.02|  2100700| 667|         9|3054290|    84889|  fall|2002.0|Studio Pierrot|     Action|
# +--------+-------------+-------------+----+-----------+--------+---------------+-------------+--------------------+-----+---------+----+----------+-------+---------+------+------+--------------+-----------+
